# %% [markdown]
# # Analysis of Cafe sales
#
# In this notebook we will do a EDA of cafe sales data!

# %% [markdown]
# ## Dependecies

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read in data

# %%
df = pd.read_csv("dirty_cafe_sales.csv")

# %% [markdown]
# ## EDA
#
# Initialy we have 10.000 row of data with 8 features and all of them are of object Dtype! Initialy we have 10.000 unique transactions.

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.shape
# Out:
# (10000, 8)

# %%
df["Transaction ID"].nunique()
# Out:
# 10000

# %%
df[df.drop(columns=["Transaction ID"]).duplicated()]
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 675     TXN_2601689     Salad        4            5.0        20.0
# 1367    TXN_5566652     Juice        5            3.0        15.0
# 1521    TXN_6817795       Tea        1            1.5         1.5
# 1949    TXN_8997048     Juice        1            3.0         3.0
# 2454    TXN_2490185     Salad        4            5.0        20.0
# ...             ...       ...      ...            ...         ...
# 9898    TXN_8999360     Juice        3            3.0         9.0
# 9909    TXN_2112522  Sandwich        5            4.0        20.0
# 9930    TXN_4428252  Sandwich        3            4.0        12.0
# 9967    TXN_8563793     Juice        4            3.0        12.0
# 9989    TXN_1741685     Juice        5            3.0        15.0
#
#       Payment Method  Location Transaction Date
# 675   Digital Wallet  Takeaway       2023-01-14
# 1367     Credit Card       NaN       2023-09-16
# 1521            Cash  Takeaway       2023-09-12
# 1949             NaN  In-store       2023-12-05
# 2454     Credit Card  In-store       2023-12-18
# ...              ...       ...              ...
# 9898            Cash  Takeaway       2023-09-27
# 9909  Digital Wallet  Takeaway       2023-04-30
# 9930             NaN  Takeaway       2023-10-31
# 9967             NaN  In-store       2023-03-26
# 9989            Cash       NaN       2023-08-18
#
# [141 rows x 8 columns]

# %%
df_no_trans = df.drop(columns=["Transaction ID"])

# %%
df_no_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              9667 non-null   object
#  1   Quantity          9862 non-null   object
#  2   Price Per Unit    9821 non-null   object
#  3   Total Spent       9827 non-null   object
#  4   Payment Method    7421 non-null   object
#  5   Location          6735 non-null   object
#  6   Transaction Date  9841 non-null   object
# dtypes: object(7)
# memory usage: 547.0+ KB

# %%
df_no_trans.columns
# Out:
# Index(['Item', 'Quantity', 'Price Per Unit', 'Total Spent', 'Payment Method',
#        'Location', 'Transaction Date'],
#       dtype='object')

# %%
df["Quantity"].dtype
# Out:
# Int64Dtype()

# %%
# df_no_trans["Quantity"] = df_no_trans["Quantity"].astype(dtype="int64", errors="ignore")
df["Quantity"] = pd.to_numeric(df["Quantity"], errors="coerce").astype("Int64")

# %%
# df_no_trans["Price Per Unit"] = df_no_trans["Price Per Unit"].astype(dtype="float64", errors="ignore")
df["Price Per Unit"] = pd.to_numeric(df["Price Per Unit"], errors="coerce").astype("Float64")

# %%
# df_no_trans["Total Spent"] = df_no_trans["Total Spent"].astype(dtype="float64", errors="ignore")
df["Total Spent"] = pd.to_numeric(df["Total Spent"], errors="coerce").astype("Float64")

# %%
df_no_trans["Transaction Date"] = pd.to_datetime(df_no_trans["Transaction Date"], format="%Y-%m-%d", errors="coerce")

# %%
df_no_trans.head()
# Out:
#      Item Quantity Price Per Unit Total Spent  Payment Method  Location  \
# 0  Coffee        2            2.0         4.0     Credit Card  Takeaway
# 1    Cake        4            3.0        12.0            Cash  In-store
# 2  Cookie        4            1.0       ERROR     Credit Card  In-store
# 3   Salad        2            5.0        10.0         UNKNOWN   UNKNOWN
# 4  Coffee        2            2.0         4.0  Digital Wallet  In-store
#
#   Transaction Date
# 0       2023-09-08
# 1       2023-05-16
# 2       2023-07-19
# 3       2023-04-27
# 4       2023-06-11

# %%
df_no_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              9667 non-null   object
#  1   Quantity          9862 non-null   object
#  2   Price Per Unit    9821 non-null   object
#  3   Total Spent       9827 non-null   object
#  4   Payment Method    7421 non-null   object
#  5   Location          6735 non-null   object
#  6   Transaction Date  9540 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(6)
# memory usage: 547.0+ KB

# %%
## format="%Y%m%d", errors="coerce"

# %%
df_no_trans[['Quantity', 'Price Per Unit', 'Total Spent']].hist(figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df_no_trans[['Quantity', 'Price Per Unit', 'Total Spent']].hist(figsize=(10,10))
#
# File c:\Users\Sebastian\Systementor\EC\Kortkurser\PythonprogrammeringMedAi\Lektioner\EOBPAH25KD_Lektion_09\venv\Lib\site-packages\pandas\plotting\_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)    248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
#     261     sharex=sharex,
#     262     sharey=sharey,
#     263     figsize=figsize,
#     264     layout=layout,
#     265     legend=legend,
#     266     bins=bins,
#     267     **kwargs,
#     268 )
#
# File c:\Users\Sebastian\Systementor\EC\Kortkurser\PythonprogrammeringMedAi\Lektioner\EOBPAH25KD_Lektion_09\venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:549, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     546 naxes = len(data.columns)
#     548 if naxes == 0:
# --> 549     raise ValueError(
#     550         "hist method requires numerical or datetime columns, nothing to plot."
#     551     )
#     553 fig, axes = create_subplots(
#     554     naxes=naxes,
#     555     ax=ax,
#    (...)    560     layout=layout,
#     561 )
#     562 _axes = flatten_axes(axes)
#
# ValueError: hist method requires numerical or datetime columns, nothing to plot.

# %%
df_no_trans[['Quantity', 'Price Per Unit', 'Total Spent', 'Transaction Date']].hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Transaction Date'}>]], dtype=object)
